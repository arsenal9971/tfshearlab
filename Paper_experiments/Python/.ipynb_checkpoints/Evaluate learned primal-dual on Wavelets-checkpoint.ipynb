# %% [markdown]
# # <center> Evaluate Learned primal dual </center>

# %%
import adler
adler.util.gpu.setup_one_gpu(2)


from adler.odl.phantom import random_phantom as random_phantom_jonas
from adler.tensorflow import prelu, cosine_decay

import tensorflow as tf
import numpy as np
import odl
import odl.contrib.tensorflow
import warnings
warnings.filterwarnings('ignore')
import math
# Out:
# Picking GPU 2

# %%
np.random.seed(0)
#name = os.path.splitext(os.path.basename(__file__))[0]
name = os.path.splitext(os.getcwd())[0]+'/checkpoints'

# %% [markdown]
# **Define space**

# %%
size = 100
meas_p_angle = 5.0
#meas_p_angle = 2.0
missing_wedge_angle = 20
#nimages = 10000
full = 0
detector_sample = size+300
#detector_sample = size
impl = 'astra_cuda'

# %%
# Create ODL data structures
space = odl.uniform_discr(
        min_pt=[-size/2, -size/2], max_pt=[size/2, size/2],
        shape=[size, size], nodes_on_bdry=True, dtype='float32')

# %%
n_angles = int((180 - 2 * missing_wedge_angle * (not full)) * \
        (1 / meas_p_angle))
n_angles = math.floor(n_angles)

# %%
mis_wedge_pi = missing_wedge_angle * np.pi/180

# %%
mis_wedge_pi*180/np.pi
# Out:
# 20.0

# %%
(np.pi + mis_wedge_pi * full - mis_wedge_pi * (not full) \
            - meas_p_angle*np.pi/180)*180/np.pi
# Out:
# 155.0

# %%
angle_partition = odl.uniform_partition(
        mis_wedge_pi,
        np.pi + mis_wedge_pi * full - mis_wedge_pi * (not full) \
            - meas_p_angle*np.pi/180,
        n_angles, nodes_on_bdry=True)

# %%
angle_partition
# Out:
# uniform_partition(0.3491, 2.705, 28, nodes_on_bdry=True)

# %%
0.3491*180/np.pi
# Out:
# 20.00195662801704

# %%
2.749*180/np.pi
# Out:
# 157.5060978814633

# %%
detector_partition = odl.uniform_partition(-size/2, size/2,
                                               detector_sample,
                                               nodes_on_bdry=True)

# %%
geometry = odl.tomo.Parallel2dGeometry(angle_partition, detector_partition)

# %%
operator = odl.tomo.RayTransform(space, geometry, impl=impl)

# %%
# Ensure operator has fixed operator norm for scale invariance
opnorm = odl.power_method_opnorm(operator)
operator = (1 / opnorm) * operator

# %%
# Create tensorflow layer from odl operator
odl_op_layer = odl.contrib.tensorflow.as_tensorflow_layer(operator,
                                                          'RayTransform')
odl_op_layer_adjoint = odl.contrib.tensorflow.as_tensorflow_layer(operator.adjoint,
                                                                  'RayTransformAdjoint')

# %%
# User selected paramters
n_data = 5
n_iter = 10
n_primal = 5
n_dual = 5

# %%
def generate_data(validation=False):
    """Generate a set of random data."""
    n_generate = 1 if validation else n_data

    y_arr = np.empty((n_generate, operator.range.shape[0], operator.range.shape[1], 1), dtype='float32')
    x_true_arr = np.empty((n_generate,space.shape[1],space.shape[2], space.shape[0]), dtype='float32')

    for i in range(n_generate):
        if validation:
            phantom = shearan(odl.phantom.shepp_logan(space_image, True))
        else:
            phantom = shearan(random_phantom(space_image))

        data = operator(phantom)
        noisy_data = data + odl.phantom.white_noise(operator.range) * np.mean(np.abs(data)) * 0.05

        for j in range(x_true_arr.shape[3]):
            x_true_arr[i,:,:,:][:,:,j] = phantom[j,:,:]
        
        y_arr[i, ..., 0] = noisy_data
        
    return y_arr, x_true_arr

# %%
with tf.name_scope('placeholders'):
    x_true = tf.placeholder(tf.float32, shape=[None, size, size, 1], name="x_true")
    y_rt = tf.placeholder(tf.float32, shape=[None, operator.range.shape[0], operator.range.shape[1], 1], name="y_rt")
    is_training = tf.placeholder(tf.bool, shape=(), name='is_training')

# %%
def apply_conv(x, filters=32):
    return tf.layers.conv2d(x, filters=filters, kernel_size=3, padding='SAME',
                            kernel_initializer=tf.contrib.layers.xavier_initializer())

# %%
primal_values = []
dual_values = []

# %%
with tf.name_scope('tomography'):
    with tf.name_scope('initial_values'):
        primal = tf.concat([tf.zeros_like(x_true)] * n_primal, axis=-1)
        dual = tf.concat([tf.zeros_like(y_rt)] * n_dual, axis=-1)

    for i in range(n_iter):
        with tf.variable_scope('dual_iterate_{}'.format(i)):
            evalop = odl_op_layer(primal[..., 1:2])
            update = tf.concat([dual, evalop, y_rt], axis=-1)

            update = prelu(apply_conv(update), name='prelu_1')
            update = prelu(apply_conv(update), name='prelu_2')
            update = apply_conv(update, filters=n_dual)
            dual = dual + update

        with tf.variable_scope('primal_iterate_{}'.format(i)):
            evalop = odl_op_layer_adjoint(dual[..., 0:1])
            update = tf.concat([primal, evalop], axis=-1)

            update = prelu(apply_conv(update), name='prelu_1')
            update = prelu(apply_conv(update), name='prelu_2')
            update = apply_conv(update, filters=n_primal)
            primal = primal + update

        primal_values.append(primal)
        dual_values.append(dual)

    x_result = primal[..., 0:1]

# %%
# Initialize all TF var\iables
sess.run(tf.global_variables_initializer())

# %%
ckp_name = name+'_lpd_wavelets/checkpoints'

# %%
# Add op to save and restore
saver = tf.train.Saver()

if 1:
    saver.restore(sess,adler.tensorflow.util.default_checkpoint_path(ckp_name))
# Out:
# INFO:tensorflow:Restoring parameters from /store/kepler/datastore/andrade/GitHub_repos/tomography/LPD_benchmark/checkpoints_size256_mpa5_mw40_ds556_max_noise/checkpoints.ckpt

# %% [markdown]
# ### First setting

# %%
print('size'+str(size)+'_mpa'+str(meas_p_angle)+'_mw'+str(2*missing_wedge_angle)+'_ds'+str(detector_sample))
# Out:
# size100_mpa5_mw40_ds100

# %%
# Generate validation data
y_arr_validate, x_true_arr_validate = generate_data(validation=True)

# %%
primal_values_result, dual_values_result = sess.run([primal_values, dual_values],
                      feed_dict={x_true: x_true_arr_validate,
                                 y_rt: y_arr_validate,
                                 is_training: False})

# %%
import matplotlib.pyplot as plt
from skimage.measure import compare_ssim as ssim
from skimage.measure import compare_psnr as psnr

print(ssim(primal_values_result[-1][0, ..., 0], x_true_arr_validate[0, ..., 0]))
print(psnr(primal_values_result[-1][0, ..., 0], x_true_arr_validate[0, ..., 0], data_range=1))
# Out:
# 0.823244655643
# 21.708426755

# %%
path2img = './results_'+'size'+str(size)+'_mpa'+str(meas_p_angle)+'_mw'+str(2*missing_wedge_angle)+'_ds'+str(detector_sample)+'.png'

# %%
plt.figure(figsize=(6,6))
plt.imshow(primal_values_result[-1][0, ..., 0])
plt.axis('off')
plt.savefig(path2img, transparent = True, bbox_inches = 'tight', pad_inches = 0.0)

# %% [markdown]
# ### Second setting

# %%
print('size'+str(size)+'_mpa'+str(meas_p_angle)+'_mw'+str(2*missing_wedge_angle)+'_ds'+str(detector_sample))
# Out:
# size100_mpa5_mw40_ds250

# %%
# Generate validation data
y_arr_validate, x_true_arr_validate = generate_data(validation=True)

# %%
primal_values_result, dual_values_result = sess.run([primal_values, dual_values],
                      feed_dict={x_true: x_true_arr_validate,
                                 y_rt: y_arr_validate,
                                 is_training: False})

# %%
import matplotlib.pyplot as plt
from skimage.measure import compare_ssim as ssim
from skimage.measure import compare_psnr as psnr

print(ssim(primal_values_result[-1][0, ..., 0], x_true_arr_validate[0, ..., 0]))
print(psnr(primal_values_result[-1][0, ..., 0], x_true_arr_validate[0, ..., 0], data_range=1))
# Out:
# 0.931093012781
# 26.7244236695

# %%
path2img = './results_'+'size'+str(size)+'_mpa'+str(meas_p_angle)+'_mw'+str(2*missing_wedge_angle)+'_ds'+str(detector_sample)+'.png'

# %%
plt.figure(figsize=(6,6))
plt.imshow(primal_values_result[-1][0, ..., 0])
plt.axis('off')
plt.savefig(path2img, transparent = True, bbox_inches = 'tight', pad_inches = 0.0)

# %% [markdown]
# ### Third setting

# %%
print('size'+str(size)+'_mpa'+str(meas_p_angle)+'_mw'+str(2*missing_wedge_angle)+'_ds'+str(detector_sample))
# Out:
# size100_mpa5_mw20_ds100

# %%
# Generate validation data
y_arr_validate, x_true_arr_validate = generate_data(validation=True)

# %%
primal_values_result, dual_values_result = sess.run([primal_values, dual_values],
                      feed_dict={x_true: x_true_arr_validate,
                                 y_rt: y_arr_validate,
                                 is_training: False})

# %%
import matplotlib.pyplot as plt
from skimage.measure import compare_ssim as ssim
from skimage.measure import compare_psnr as psnr

print(ssim(primal_values_result[-1][0, ..., 0], x_true_arr_validate[0, ..., 0]))
print(psnr(primal_values_result[-1][0, ..., 0], x_true_arr_validate[0, ..., 0], data_range=1))
# Out:
# 0.851378099205
# 23.4637211592

# %%
path2img = './results_'+'size'+str(size)+'_mpa'+str(meas_p_angle)+'_mw'+str(2*missing_wedge_angle)+'_ds'+str(detector_sample)+'.png'

# %%
plt.figure(figsize=(6,6))
plt.imshow(primal_values_result[-1][0, ..., 0])
plt.axis('off')
plt.savefig(path2img, transparent = True, bbox_inches = 'tight', pad_inches = 0.0)

# %% [markdown]
# ### Fourth setting

# %%
print('size'+str(size)+'_mpa'+str(meas_p_angle)+'_mw'+str(2*missing_wedge_angle)+'_ds'+str(detector_sample))
# Out:
# size100_mpa5_mw20_ds250

# %%
# Generate validation data
y_arr_validate, x_true_arr_validate = generate_data(validation=True)

# %%
primal_values_result, dual_values_result = sess.run([primal_values, dual_values],
                      feed_dict={x_true: x_true_arr_validate,
                                 y_rt: y_arr_validate,
                                 is_training: False})

# %%
import matplotlib.pyplot as plt
from skimage.measure import compare_ssim as ssim
from skimage.measure import compare_psnr as psnr

print(ssim(primal_values_result[-1][0, ..., 0], x_true_arr_validate[0, ..., 0]))
print(psnr(primal_values_result[-1][0, ..., 0], x_true_arr_validate[0, ..., 0], data_range=1))
# Out:
# 0.935959938399
# 27.6290805784

# %%
path2img = './results_'+'size'+str(size)+'_mpa'+str(meas_p_angle)+'_mw'+str(2*missing_wedge_angle)+'_ds'+str(detector_sample)+'.png'

# %%
plt.figure(figsize=(6,6))
plt.imshow(primal_values_result[-1][0, ..., 0])
plt.axis('off')
plt.savefig(path2img, transparent = True, bbox_inches = 'tight', pad_inches = 0.0)

# %% [markdown]
# ### Fifth setting

# %%
print('size'+str(size)+'_mpa'+str(meas_p_angle)+'_mw'+str(2*missing_wedge_angle)+'_ds'+str(detector_sample))
# Out:
# size256_mpa5_mw40_ds256

# %%
# Generate validation data
y_arr_validate, x_true_arr_validate = generate_data(validation=True)

# %%
primal_values_result, dual_values_result = sess.run([primal_values, dual_values],
                      feed_dict={x_true: x_true_arr_validate,
                                 y_rt: y_arr_validate,
                                 is_training: False})

# %%
import matplotlib.pyplot as plt
from skimage.measure import compare_ssim as ssim
from skimage.measure import compare_psnr as psnr

print(ssim(primal_values_result[-1][0, ..., 0], x_true_arr_validate[0, ..., 0]))
print(psnr(primal_values_result[-1][0, ..., 0], x_true_arr_validate[0, ..., 0], data_range=1))
# Out:
# 0.878633828743
# 22.0203196058

# %%
path2img = './results_'+'size'+str(size)+'_mpa'+str(meas_p_angle)+'_mw'+str(2*missing_wedge_angle)+'_ds'+str(detector_sample)+'.png'

# %%
plt.figure(figsize=(6,6))
plt.imshow(primal_values_result[-1][0, ..., 0])
plt.axis('off')
plt.savefig(path2img, transparent = True, bbox_inches = 'tight', pad_inches = 0.0)

# %% [markdown]
# ### Sixth setting

# %%
print('size'+str(size)+'_mpa'+str(meas_p_angle)+'_mw'+str(2*missing_wedge_angle)+'_ds'+str(detector_sample))
# Out:
# size256_mpa5_mw40_ds556

# %%
# Generate validation data
y_arr_validate, x_true_arr_validate = generate_data(validation=True)

# %%
primal_values_result, dual_values_result = sess.run([primal_values, dual_values],
                      feed_dict={x_true: x_true_arr_validate,
                                 y_rt: y_arr_validate,
                                 is_training: False})

# %%
import matplotlib.pyplot as plt
from skimage.measure import compare_ssim as ssim
from skimage.measure import compare_psnr as psnr

print(ssim(primal_values_result[-1][0, ..., 0], x_true_arr_validate[0, ..., 0]))
print(psnr(primal_values_result[-1][0, ..., 0], x_true_arr_validate[0, ..., 0], data_range=1))
# Out:
# 0.862885912166
# 22.1583799466

# %%
path2img = './results_'+'size'+str(size)+'_mpa'+str(meas_p_angle)+'_mw'+str(2*missing_wedge_angle)+'_ds'+str(detector_sample)+'.png'

# %%
plt.figure(figsize=(6,6))
plt.imshow(primal_values_result[-1][0, ..., 0])
plt.axis('off')
plt.savefig(path2img, transparent = True, bbox_inches = 'tight', pad_inches = 0.0)

# %% [markdown]
# ### Seventh setting

# %%
print('size'+str(size)+'_mpa'+str(meas_p_angle)+'_mw'+str(2*missing_wedge_angle)+'_ds'+str(detector_sample))
# Out:
# size256_mpa5_mw20_ds256

# %%
# Generate validation data
y_arr_validate, x_true_arr_validate = generate_data(validation=True)

# %%
primal_values_result, dual_values_result = sess.run([primal_values, dual_values],
                      feed_dict={x_true: x_true_arr_validate,
                                 y_rt: y_arr_validate,
                                 is_training: False})

# %%
import matplotlib.pyplot as plt
from skimage.measure import compare_ssim as ssim
from skimage.measure import compare_psnr as psnr

print(ssim(primal_values_result[-1][0, ..., 0], x_true_arr_validate[0, ..., 0]))
print(psnr(primal_values_result[-1][0, ..., 0], x_true_arr_validate[0, ..., 0], data_range=1))
# Out:
# 0.958206096489
# 27.2920152678

# %%
path2img = './results_'+'size'+str(size)+'_mpa'+str(meas_p_angle)+'_mw'+str(2*missing_wedge_angle)+'_ds'+str(detector_sample)+'.png'

# %%
plt.figure(figsize=(6,6))
plt.imshow(primal_values_result[-1][0, ..., 0])
plt.axis('off')
plt.savefig(path2img, transparent = True, bbox_inches = 'tight', pad_inches = 0.0)

# %% [markdown]
# ### Eighth setting

# %%
print('size'+str(size)+'_mpa'+str(meas_p_angle)+'_mw'+str(2*missing_wedge_angle)+'_ds'+str(detector_sample))
# Out:
# size256_mpa5_mw20_ds556

# %%
# Generate validation data
y_arr_validate, x_true_arr_validate = generate_data(validation=True)

# %%
primal_values_result, dual_values_result = sess.run([primal_values, dual_values],
                      feed_dict={x_true: x_true_arr_validate,
                                 y_rt: y_arr_validate,
                                 is_training: False})

# %%
import matplotlib.pyplot as plt
from skimage.measure import compare_ssim as ssim
from skimage.measure import compare_psnr as psnr

print(ssim(primal_values_result[-1][0, ..., 0], x_true_arr_validate[0, ..., 0]))
print(psnr(primal_values_result[-1][0, ..., 0], x_true_arr_validate[0, ..., 0], data_range=1))
# Out:
# 0.932188091016
# 25.7051629981

# %%
path2img = './results_'+'size'+str(size)+'_mpa'+str(meas_p_angle)+'_mw'+str(2*missing_wedge_angle)+'_ds'+str(detector_sample)+'.png'

# %%
plt.figure(figsize=(6,6))
plt.imshow(primal_values_result[-1][0, ..., 0])
plt.axis('off')
plt.savefig(path2img, transparent = True, bbox_inches = 'tight', pad_inches = 0.0)

# %% [markdown]
# ### First setting maximum noise

# %%
print('size'+str(size)+'_mpa'+str(meas_p_angle)+'_mw'+str(2*missing_wedge_angle)+'_ds'+str(detector_sample))
# Out:
# size256_mpa5_mw40_ds256

# %%
ckp_name
# Out:
# '/store/kepler/datastore/andrade/GitHub_repos/tomography/LPD_benchmark/checkpoints_size256_mpa5_mw40_ds256_max_noise/checkpoints'

# %%
# Generate validation data
y_arr_validate, x_true_arr_validate = generate_data(validation=True)

# %%
primal_values_result, dual_values_result = sess.run([primal_values, dual_values],
                      feed_dict={x_true: x_true_arr_validate,
                                 y_rt: y_arr_validate,
                                 is_training: False})

# %%
import matplotlib.pyplot as plt
from skimage.measure import compare_ssim as ssim
from skimage.measure import compare_psnr as psnr

print(ssim(primal_values_result[-1][0, ..., 0], x_true_arr_validate[0, ..., 0]))
print(psnr(primal_values_result[-1][0, ..., 0], x_true_arr_validate[0, ..., 0], data_range=1))
# Out:
# 0.834712856524
# 20.732796273

# %%
path2img = './results_'+'size'+str(size)+'_mpa'+str(meas_p_angle)+'_mw'+str(2*missing_wedge_angle)+'_ds'+str(detector_sample)+'_max_noise.png'

# %%
plt.figure(figsize=(6,6))
plt.imshow(primal_values_result[-1][0, ..., 0])
plt.axis('off')
plt.savefig(path2img, transparent = True, bbox_inches = 'tight', pad_inches = 0.0)

# %% [markdown]
# ### Second setting maximum noise

# %%
print('size'+str(size)+'_mpa'+str(meas_p_angle)+'_mw'+str(2*missing_wedge_angle)+'_ds'+str(detector_sample))
# Out:
# size256_mpa5_mw40_ds556

# %%
ckp_name
# Out:
# '/store/kepler/datastore/andrade/GitHub_repos/tomography/LPD_benchmark/checkpoints_size256_mpa5_mw40_ds556_max_noise/checkpoints'

# %%
# Generate validation data
y_arr_validate, x_true_arr_validate = generate_data(validation=True)

# %%
primal_values_result, dual_values_result = sess.run([primal_values, dual_values],
                      feed_dict={x_true: x_true_arr_validate,
                                 y_rt: y_arr_validate,
                                 is_training: False})

# %%
import matplotlib.pyplot as plt
from skimage.measure import compare_ssim as ssim
from skimage.measure import compare_psnr as psnr

print(ssim(primal_values_result[-1][0, ..., 0], x_true_arr_validate[0, ..., 0]))
print(psnr(primal_values_result[-1][0, ..., 0], x_true_arr_validate[0, ..., 0], data_range=1))
# Out:
# 0.850845074586
# 21.3719915868

# %%
path2img = './results_'+'size'+str(size)+'_mpa'+str(meas_p_angle)+'_mw'+str(2*missing_wedge_angle)+'_ds'+str(detector_sample)+'_max_noise.png'

# %%
plt.figure(figsize=(6,6))
plt.imshow(primal_values_result[-1][0, ..., 0])
plt.axis('off')
plt.savefig(path2img, transparent = True, bbox_inches = 'tight', pad_inches = 0.0)

# %% [markdown]
# ### First setting maximum noise and phantom training

# %%
ckp_name = name+'_size'+str(size)+'_mpa'+str(meas_p_angle)+'_mw'+str(2*missing_wedge_angle)+'_ds'+str(detector_sample)+'_max_noise_phantom_gen/checkpoints'

# %%
adler.tensorflow.util.default_checkpoint_path(ckp_name)
# Out:
# '/store/kepler/datastore/andrade/GitHub_repos/tomography/LPD_benchmark/checkpoints_size100_mpa5.0_mw40_ds100_max_noise_phantom_gen/checkpoints.ckpt'

# %%
# Add op to save and restore
saver = tf.train.Saver()

if 1:
    saver.restore(sess,adler.tensorflow.util.default_checkpoint_path(ckp_name))
# Out:
# INFO:tensorflow:Restoring parameters from /store/kepler/datastore/andrade/GitHub_repos/tomography/LPD_benchmark/checkpoints_size100_mpa5.0_mw40_ds100_max_noise_phantom_gen/checkpoints.ckpt

# %%
# Generate validation data
y_arr_validate, x_true_arr_validate = generate_data(validation=True)

# %%
primal_values_result, dual_values_result = sess.run([primal_values, dual_values],
                      feed_dict={x_true: x_true_arr_validate,
                                 y_rt: y_arr_validate,
                                 is_training: False})

# %%
import matplotlib.pyplot as plt
from skimage.measure import compare_ssim as ssim
from skimage.measure import compare_psnr as psnr

print(ssim(primal_values_result[-1][0, ..., 0], x_true_arr_validate[0, ..., 0]))
print(psnr(primal_values_result[-1][0, ..., 0], x_true_arr_validate[0, ..., 0], data_range=1))
# Out:
# 0.677883415995
# 17.395607117

# %%
path2img = './results_'+'size'+str(size)+'_mpa'+str(meas_p_angle)+'_mw'+str(2*missing_wedge_angle)+'_ds'+str(detector_sample)+'_max_noise_phantom_gen.png'

# %%
plt.figure(figsize=(6,6))
plt.imshow(primal_values_result[-1][0, ..., 0])
plt.axis('off')
plt.savefig(path2img, transparent = True, bbox_inches = 'tight', pad_inches = 0.0)

# %% [markdown]
# ### Second setting maximum noise and phantom training

# %%
ckp_name = name+'_size'+str(size)+'_mpa'+str(meas_p_angle)+'_mw'+str(2*missing_wedge_angle)+'_ds'+str(detector_sample)+'_max_noise_phantom_gen/checkpoints'

# %%
adler.tensorflow.util.default_checkpoint_path(ckp_name)
# Out:
# '/store/kepler/datastore/andrade/GitHub_repos/tomography/LPD_benchmark/checkpoints_size100_mpa5.0_mw40_ds400_max_noise_phantom_gen/checkpoints.ckpt'

# %%
# Add op to save and restore
saver = tf.train.Saver()

if 1:
    saver.restore(sess,adler.tensorflow.util.default_checkpoint_path(ckp_name))
# Out:
# INFO:tensorflow:Restoring parameters from /store/kepler/datastore/andrade/GitHub_repos/tomography/LPD_benchmark/checkpoints_size100_mpa5.0_mw40_ds400_max_noise_phantom_gen/checkpoints.ckpt

# %%
# Generate validation data
y_arr_validate, x_true_arr_validate = generate_data(validation=True)

# %%
primal_values_result, dual_values_result = sess.run([primal_values, dual_values],
                      feed_dict={x_true: x_true_arr_validate,
                                 y_rt: y_arr_validate,
                                 is_training: False})

# %%
import matplotlib.pyplot as plt
from skimage.measure import compare_ssim as ssim
from skimage.measure import compare_psnr as psnr

print(ssim(primal_values_result[-1][0, ..., 0], x_true_arr_validate[0, ..., 0]))
print(psnr(primal_values_result[-1][0, ..., 0], x_true_arr_validate[0, ..., 0], data_range=1))
# Out:
# 0.518431785915
# 16.9989013246

# %%
path2img = './results_'+'size'+str(size)+'_mpa'+str(meas_p_angle)+'_mw'+str(2*missing_wedge_angle)+'_ds'+str(detector_sample)+'_max_noise_phantom_gen.png'

# %%
plt.figure(figsize=(6,6))
plt.imshow(primal_values_result[-1][0, ..., 0])
plt.axis('off')
plt.savefig(path2img, transparent = True, bbox_inches = 'tight', pad_inches = 0.0)
